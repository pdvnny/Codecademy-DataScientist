# %% [markdown]
# ## Copyright 2021 Parker Dunn parker_dunn@outlook.com
#
# #### Alternate: pgdunn@bu.edu & pdunn91@gmail.com
# #### November 13th, 2021
#
# __Career Path: Data Scientist__
# __Section: Python Fundamentals__
# __Topic: Python Dictionaries__
#
#
# ### Codecademy - Medical Insurance

# %% [markdown]
# ### Assignment Context
#
# This mini-project is meant to be a demonstration of some fundamentals of Python. I am trying to complete the data scientist path on Codecademy and practice Python, so I have gone back to some content that I have learned already.
#
# ### Assignment Description
#
# "You have been asked to create a program that organizaes and updates medical records efficiently.
#
# In this project, you wil use your new knowledge of Python directionaries to create a database of medical records for patients."

# %%
# Add your code here
medical_costs = {}

medical_costs["Marina"] = 6607.0
medical_costs["Vinay"] = 3225.0

medical_costs.update({"Connie": 8886.0, "Isaac": 16444.0, "Valentina": 6420.0})
print(medical_costs)

medical_costs["Vinary"] = 3325.0
print(medical_costs)

total_cost = 0
for (key, value) in medical_costs.items():
  total_cost += value
print("\n",total_cost)

print("\nAverage Insurance Cost: {}".format(total_cost/len(medical_costs)))

# map maps patient names to ages
names = ["Marina", "Vinay", "Connie", "Isaac", "Valentina"]
ages = [27, 24, 43, 35, 52]

zipped_ages = zip(names, ages)
names_to_ages = {key:value for (key, value) in zipped_ages}
print("\n",names_to_ages,"\n")

marina_age = names_to_ages.get("Marina", None)
print("Marina's page is {}\n".format(marina_age))

# Third dection to represent a database of medical records that includes
# name, age, sex, gender, BMI, number of children, smoker status, insurance cost

medical_records = {}
medical_records['Marina'] = {"Age": 27,
                             "Sex": "Female",
                             "BMI": 31.1,
                             "Children": 2,
                             "Smoker": "Non-smoker",
                             "Insurance_cost": 6607.0}
medical_records["Vinay"] = {"Age": 24,
                            "Sex": "Male",
                            "BMI": 25.3,
                            "Children": 0,
                            "Smoker": "Non-smoker",
                            "Insurance_cost": 3225.0}

medical_records["Connie"] = {"Age": 43,
                             "Sex": "Female",
                             "BMI": 25.3,
                             "Children": 3,
                             "Smoker": "Non-smoker",
                             "Insurance_cost": 8886.0}

medical_records["Isaac"] = {"Age": 35,
                            "Sex": "Male",
                            "BMI": 20.6,
                            "Children": 4,
                            "Smoker": "Smoker",
                            "Insurance_cost": 6420.0}

medical_records["Valentina"] = {"Age": 52,
                            "Sex": "Female",
                            "BMI": 18.7,
                            "Children": 1,
                            "Smoker": "Non-smoker",
                            "Insurance_cost": 6420.0}

for key, value in medical_records.items():
  print(key, value, "\n")

print("\nConnie's insurance cost is {} dollars.\n".format(medical_records["Connie"]["Insurance_cost"]))

medical_records.pop("Vinay")

for key, value in medical_records.items():
  print("{0} is a {1} year old {2} {3} with a BMI of {4} and insurance cost of {5}\n".format(key, value["Age"], value["Sex"], value["Smoker"], value["BMI"], value["Insurance_cost"]))

def update_medical_records(name, med_data):
  medical_records[name] = med_data
# Out:
# {'Marina': 6607.0, 'Vinay': 3225.0, 'Connie': 8886.0, 'Isaac': 16444.0, 'Valentina': 6420.0}
# {'Marina': 6607.0, 'Vinay': 3225.0, 'Connie': 8886.0, 'Isaac': 16444.0, 'Valentina': 6420.0, 'Vinary': 3325.0}
#
#  44907.0
#
# Average Insurance Cost: 7484.5
#
#  {'Marina': 27, 'Vinay': 24, 'Connie': 43, 'Isaac': 35, 'Valentina': 52}
#
# Marina's page is 27
#
# Marina {'Age': 27, 'Sex': 'Female', 'BMI': 31.1, 'Children': 2, 'Smoker': 'Non-smoker', 'Insurance_cost': 6607.0}
#
# Vinay {'Age': 24, 'Sex': 'Male', 'BMI': 25.3, 'Children': 0, 'Smoker': 'Non-smoker', 'Insurance_cost': 3225.0}
#
# Connie {'Age': 43, 'Sex': 'Female', 'BMI': 25.3, 'Children': 3, 'Smoker': 'Non-smoker', 'Insurance_cost': 8886.0}
#
# Isaac {'Age': 35, 'Sex': 'Male', 'BMI': 20.6, 'Children': 4, 'Smoker': 'Smoker', 'Insurance_cost': 6420.0}
#
# Valentina {'Age': 52, 'Sex': 'Female', 'BMI': 18.7, 'Children': 1, 'Smoker': 'Non-smoker', 'Insurance_cost': 6420.0}
#
#
# Connie's insurance cost is 8886.0 dollars.
#
# ...
